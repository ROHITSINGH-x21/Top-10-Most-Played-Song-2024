# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Here is Data of Most Popular/Played Song in 2024, We need to Show top 10 Most Played Songs.
# #1 Firstly we import the data

# %%
df = pd.read_csv('Spotify.csv')

# %%
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC All Time Rank  Track Score Spotify Streams  \
# 0    4/26/2024  QM24S2402528             1        725.4     390,470,936
# 1     5/4/2024  USUG12400910             2        545.9     323,703,884
# 2    3/19/2024  QZJ842400387             3        538.4     601,309,283
# 3    1/12/2023  USSM12209777             4        444.9   2,031,280,633
# 4    5/31/2024  USUG12403398             5        423.3     107,034,922
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# ...

# %%
df.shape
# Out:
# (4600, 29)

# %%
df.columns
# Out:
# Index(['Track', 'Album Name', 'Artist', 'Release Date', 'ISRC',
#        'All Time Rank', 'Track Score', 'Spotify Streams',
#        'Spotify Playlist Count', 'Spotify Playlist Reach',
#        'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts',
#        'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach',
#        'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
#        'Deezer Playlist Count', 'Deezer Playlist Reach',
#        'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
#        'Soundcloud Streams', 'Shazam Counts', 'TIDAL Popularity',
#        'Explicit Track'],
#       dtype='object')

# %% [markdown]
# #2 Then we need to clean data, for that we need to drop unnessecery columns

# %%
df.drop(['ISRC', 'Track Score', 
       'Spotify Playlist Count', 'Spotify Playlist Reach',
       'YouTube Likes', 'TikTok Posts',
       'TikTok Likes', 'YouTube Playlist Reach',
       'Apple Music Playlist Count', 'AirPlay Spins', 'SiriusXM Spins',
       'Deezer Playlist Count', 'Deezer Playlist Reach',
       'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations',
       'Soundcloud Streams', 'Shazam Counts', 'TIDAL Popularity','Spotify Popularity','Explicit Track'],axis='columns',inplace=True)

# %%
df.head()
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date All Time Rank Spotify Streams  YouTube Views    TikTok Views
# 0    4/26/2024             1     390,470,936     84,274,754   5,332,281,936
# 1     5/4/2024             2     323,703,884    116,347,040     208,339,025
# 2    3/19/2024             3     601,309,283    122,599,116   3,369,120,610
# 3    1/12/2023             4   2,031,280,633  1,096,100,899  14,603,725,994
# 4    5/31/2024             5     107,034,922     77,373,957             NaN

# %% [markdown]
# #3 after some cleaning we need to know Shape, Info, Describe and Null Values

# %%
df.shape
# Out:
# (4600, 8)

# %%
df.isnull().sum()
# Out:
# Track                0
# Album Name           0
# Artist               5
# Release Date         0
# All Time Rank        0
# Spotify Streams    113
# YouTube Views      308
# TikTok Views       981
# dtype: int64

# %%
df.describe().T
# Out:
#                 count unique                   top freq
# Track            4600   4370  Danza Kuduro - Cover   13
# Album Name       4600   4005      Un Verano Sin Ti   20
# Artist           4595   1999                 Drake   63
# Release Date     4600   1562              1/1/2012   38
# All Time Rank    4600   4577                 3,441    2
# Spotify Streams  4487   4425         1,655,575,417    4
# YouTube Views    4292   4290            30,913,276    2
# TikTok Views     3619   3616           158,504,854    2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Track            4600 non-null   object
#  1   Album Name       4600 non-null   object
#  2   Artist           4595 non-null   object
#  3   Release Date     4600 non-null   object
#  4   All Time Rank    4600 non-null   object
#  5   Spotify Streams  4487 non-null   object
#  6   YouTube Views    4292 non-null   object
#  7   TikTok Views     3619 non-null   object
# dtypes: object(8)
# memory usage: 287.6+ KB

# %% [markdown]
# #4 Here we removing commas from the values in specified columns

# %%
views_list = ['Spotify Streams'	,'YouTube Views','TikTok Views']
for x in views_list:
    df[x]=df[x].str.replace(',','')

# %% [markdown]
# #5 We got the info from 'isnull' that in these column their are so much null value, So we need to fill them with '0'

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Track              0
# Album Name         0
# Artist             0
# Release Date       0
# All Time Rank      0
# Spotify Streams    0
# YouTube Views      0
# TikTok Views       0
# dtype: int64

# %% [markdown]
# #6 After Geting Info we got that ('Spotify Streams'	,'YouTube Views','TikTok Views') these 3 columns are object.
# for counting Views/streams we need data in 'int' form.
# so we need chnage their data type for (object) to (int).

# %%
for x in views_list:
    df[x] = df[x].astype(np.int64)

# %% [markdown]
# #7 after changing data type we create a new column for total views using of these 3 Columns

# %%
df['Total Views'] = df['Spotify Streams'] +	 df['YouTube Views'] + df['TikTok Views']

# %%
df
# Out:
#                                 Track                        Album Name  \
# 0                 MILLION DOLLAR BABY      Million Dollar Baby - Single
# 1                         Not Like Us                       Not Like Us
# 2          i like the way you kiss me        I like the way you kiss me
# 3                             Flowers                  Flowers - Single
# 4                             Houdini                           Houdini
# ...                               ...                               ...
# 4595                For the Last Time                 For the Last Time
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date All Time Rank  Spotify Streams  \
# ...

# %% [markdown]
# #8 then We need to ascend data from high to low to get top 10 Songs

# %%
final_data = df.sort_values(by='Total Views',ascending=False).head(10)

# %%
final_data
# Out:
#                           Track                 Album Name  \
# 1024   Monkeys Spinning Monkeys          SteamFun - Single
# 1922                Love You So   The King Khan & BBQ Show
# 474                       Oh No                Cold As Ice
# 1547                 Funny Song   Vintage Oddities, Vol. 4
# 113                   Aesthetic                  Aesthetic
# 3377                  Spongebob                  Spongebob
# 1163            She Share Story            She Share Story
# 26    STAY (with Justin Bieber)  STAY (with Justin Bieber)
# 3383                     Pieces                     Pieces
# 255    love nwantiti (ah ah ah)             CKay The First
#
#                         Artist Release Date All Time Rank  Spotify Streams  \
# 1024             Kevin MacLeod    5/16/2011         1,018         11477477
# 1922  The King Khan & BBQ Show     1/1/2005         1,918         16326628
# 474                     Kreepa   12/13/2019           473         40284121
# ...

# %% [markdown]
# #9 Here is the visuals of the top 10 most played song in 2024

# %%
labels = final_data.Track
plt.style.use('ggplot')
colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231', '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe']
fig=plt.pie(final_data['Total Views'],pctdistance=01.1,autopct='%.1f %%',colors=colors,)
plt.legend(fig[0], labels, loc="upper left", bbox_to_anchor = (1.4,1))
plt.title('Top 10 Most Streamed Songs in 2024')
plt.show()
